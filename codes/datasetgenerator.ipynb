# %%
import pandas as pd
import numpy as np
data1=pd.read_csv('/content/file1 - file1.csv')
print(data1)
# Out:
#      Unnamed: 0  Daily Conf  Daily Rec  Daily Death  Imported_daily
# 0           NaN        11.0       10.0          9.0            15.0
# 1           NaN        14.0        2.0         13.0             8.0
# 2           NaN        13.0       18.0         19.0            14.0
# 3           NaN         0.0       16.0          0.0            16.0
# 4           NaN        11.0       16.0          9.0            16.0
# ..          ...         ...        ...          ...             ...
# 360         NaN         8.0       14.0          9.0             3.0
# 361         NaN         4.0        0.0          7.0             3.0
# 362         NaN        15.0       15.0          3.0            18.0
# 363         NaN         0.0        7.0         17.0            16.0
# 364         NaN         0.0       10.0          8.0             0.0
#
# [365 rows x 5 columns]

# %% [markdown]
# # New Section

# %%
l=np.array(data1['Imported_daily'])
print(l)

# %%
def generatewindow(arr,windowsize):
  i=0
  while(i<366):
    num=i/windowsize
    if num%2==1 and i%windowsize==0:
      i+=windowsize
    else:
      arr[i]=0
      i+=1
  return arr

# %%
# def generatewindow(arr,windowsize):
#   for i in range(1,len(l)):
#     if i+7<len(l):
#       arr[i]=0
#       arr[i+1]=0
#       arr[i+2]=0
#       arr[i+3]=0
#       arr[i+4]=0
#       arr[i+5]=0
#       arr[i+6]=0
#       arr[i+7]=0
#       i+=8
#   return arr

# %%
p=generatewindow(l,8)
print(p)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-ce1eff027419> in <module>()
# ----> 1 p=generatewindow(l,8)
#       2 print(p)
#
# NameError: name 'l' is not defined
